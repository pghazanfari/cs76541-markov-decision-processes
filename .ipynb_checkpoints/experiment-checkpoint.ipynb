# %%
from lib.experiment.experiment import Experiment
import random
import numpy as np

# %%
rng = 234642
random.seed(rng)
np.random.seed(rng)

experiment = Experiment()

experiment.state[0]['frozen_lake'] = {
    'gamma': 1.0
}

experiment.state[0]['tilemap'] = {
    'gamma': 1.0
}

experiment.state[2]['frozen_lake'] = {
    'gamma': 1.0
}
experiment.state[2]['tilemap'] = {
    'gamma': 1.0
}

experiment.state[5]['tilemap'] = {
    'gamma': 0.9,
    'lr': 0.5,
    'eps_decay': 0.99,
    'max_epochs': 1000
}


experiment.state[5]['frozen_lake'] = {
    'gamma': 1.0,
    'lr': 0.25,
    'eps_decay': 0.99,
    'max_epochs': 1000
}
experiment.state[6]['frozen_lake'] = {
    'max_epochs': 1000
}

# %%
experiment.run()
# Out:
# value_iteration:  {'frozen_lake': {'gamma': 1.0}, 'tilemap': {'gamma': 1.0}}
# policy_iteration:  {'frozen_lake': {'gamma': 1.0}, 'tilemap': {'gamma': 1.0}}
# tilemap: lr=0.5, gamma=0.9, eps_decay=0.99
# frozen_lake: lr=0.25, gamma=1.0, eps_decay=0.99
# tilemap: time=0.3281271457672119, final_reward=1.0
# frozen_lake: time=1.5032870769500732, final_reward=0.5
